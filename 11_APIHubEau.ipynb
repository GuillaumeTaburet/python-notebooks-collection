# %% [markdown]
# # Requetes et visualisation de données à partir de l'API HubEAU
# site : https://hubeau.eaufrance.fr/

# %%
import requests
import pandas as pd
import folium

# %% [markdown]
# fonction permettant de gérer les différentes requètes du notebook

# %%
def requete_api(url, params=None):
    try:
        if params is not None:
            reponse = requests.get(url, params=params)
        else:
            reponse = requests.get(url)
        # Lève une exception si la requête échoue
        reponse.raise_for_status()
        return reponse.json()
    except requests.exceptions.RequestException as e:
        print(f"Erreur lors de la requête : {e}")
        return None

# %% [markdown]
# ## Test permettant d'interroger les analyse physico-chimique de l'API qualité des cours d'eau
# Lien : https://hubeau.eaufrance.fr/page/api-qualite-cours-deau

# %%
url = "https://hubeau.eaufrance.fr/api/v2/qualite_rivieres/analyse_pc"

params = {
    "libelle_commune": "Toulouse",
    "libelle_parametre": "Nitrates",
    "date_debut_prelevement": "2023-01-01",
    "date_fin_prelevement": "2024-01-01",
    "code_qualification": "1",
    "pretty": True,
    "sort": "desc",
    "fields": "longitude,latitude,libelle_station,libelle_parametre,date_prelevement,resultat,symbole_unite,mnemo_remarque,mnemo_statut,code_qualification"
}

data = requete_api(url, params=params)

if data is not None:
    df = pd.DataFrame(data)

# %% [markdown]
# ### Visualisation des stations d'analyse

# %%
# Créer une carte
f = folium.Figure(width=800, height=800)
m = folium.Map(location=[43.602566, 1.397389], zoom_start=13).add_to(f)

# Ajouter SOLAGRO à la carte
folium.Marker([43.602566, 1.397389], popup='SOLAGRO', icon=folium.Icon(color='red')).add_to(m)

# dt.data is pandas.core.series.Series
lon = df.data.apply(lambda x: x['longitude']).values
lat = df.data.apply(lambda x: x['latitude']).values
libelle_station = df.data.apply(lambda x: x['libelle_station']).values

for i in range(len(lon)):
    folium.Marker(location=[lat[i], lon[i]], popup=libelle_station[i]).add_to(m)

display(m)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_058adf96d68961d07dea2768c534ad1b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_058adf96d68961d07dea2768c534ad1b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_058adf96d68961d07dea2768c534ad1b = L.map(
#                 &quot;map_058adf96d68961d07dea2768c534ad1b&quot;,
#                 {
#                     center: [43.602566, 1.397389],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afbbe969d62aebf067cb692bd1f94ed5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_afbbe969d62aebf067cb692bd1f94ed5.addTo(map_058adf96d68961d07dea2768c534ad1b);
#
#
#             var marker_4f562d8a90c35a68694d2af222996866 = L.marker(
#                 [43.602566, 1.397389],
#                 {}
#             ).addTo(map_058adf96d68961d07dea2768c534ad1b);
#
#
#             var icon_81a1c143f5694a085c467ec94214ebc6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4f562d8a90c35a68694d2af222996866.setIcon(icon_81a1c143f5694a085c467ec94214ebc6);
#
#
#         var popup_14d8a01439bd0a01f8822f8003e9b30c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_50a0366dab815b68438a96cb74c21a81 = $(`&lt;div id=&quot;html_50a0366dab815b68438a96cb74c21a81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SOLAGRO&lt;/div&gt;`)[0];
#                 popup_14d8a01439bd0a01f8822f8003e9b30c.setContent(html_50a0366dab815b68438a96cb74c21a81);
#
#
#
#         marker_4f562d8a90c35a68694d2af222996866.bindPopup(popup_14d8a01439bd0a01f8822f8003e9b30c)
#         ;
#
#
#
#
#             var marker_bf853651c48f386e4dfc13220fc5130a = L.marker(
#                 [43.60934733, 1.419491118],
#                 {}
#             ).addTo(map_058adf96d68961d07dea2768c534ad1b);
#
#
#         var popup_54f1f15735147de92193750310ae6d5c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b73630f32c5feda6c94174bc1e43d461 = $(`&lt;div id=&quot;html_b73630f32c5feda6c94174bc1e43d461&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PECH DAVID&lt;/div&gt;`)[0];
#                 popup_54f1f15735147de92193750310ae6d5c.setContent(html_b73630f32c5feda6c94174bc1e43d461);
#
#
#
#         marker_bf853651c48f386e4dfc13220fc5130a.bindPopup(popup_54f1f15735147de92193750310ae6d5c)
#         ;
#
#
#
#
#             var marker_946a84c891f879d8dba2cb6119fde49d = L.marker(
#                 [43.664021872, 1.403577731],
#                 {}
#             ).addTo(map_058adf96d68961d07dea2768c534ad1b);
#
#
#         var popup_75e6e0c073d498a77176a184d77ef883 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_94f8eecee8f85086e0cc8016d7176e2f = $(`&lt;div id=&quot;html_94f8eecee8f85086e0cc8016d7176e2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;La Garonne au Syndicat Centre et Nord&lt;/div&gt;`)[0];
#                 popup_75e6e0c073d498a77176a184d77ef883.setContent(html_94f8eecee8f85086e0cc8016d7176e2f);
#
#
#
#         marker_946a84c891f879d8dba2cb6119fde49d.bindPopup(popup_75e6e0c073d498a77176a184d77ef883)
#         ;
#
#
#
#
#             var marker_aee1f54971f524a8dbda8d48cdbc1dae = L.marker(
#                 [43.646812257, 1.483920545],
#                 {}
#             ).addTo(map_058adf96d68961d07dea2768c534ad1b);
#
#
#         var popup_6b504caf654fb88484b4e9772dd12701 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e843367512f2c8d32521499a294efec3 = $(`&lt;div id=&quot;html_e843367512f2c8d32521499a294efec3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;La Sausse à Toulouse&lt;/div&gt;`)[0];
#                 popup_6b504caf654fb88484b4e9772dd12701.setContent(html_e843367512f2c8d32521499a294efec3);
#
#
#
#         marker_aee1f54971f524a8dbda8d48cdbc1dae.bindPopup(popup_6b504caf654fb88484b4e9772dd12701)
#         ;
#
#
#
#
#             var marker_b85dfbf7a32b54acacbf51213eaf4e2e = L.marker(
#                 [43.624924498, 1.400961721],
#                 {}
#             ).addTo(map_058adf96d68961d07dea2768c534ad1b);
#
#
#         var popup_1bafa1ed4ec7f5f54ac8ccbce04f76d4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dc4791cccfb1d8aa3a5db5198d4592b5 = $(`&lt;div id=&quot;html_dc4791cccfb1d8aa3a5db5198d4592b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;La Garonne à Blagnac&lt;/div&gt;`)[0];
#                 popup_1bafa1ed4ec7f5f54ac8ccbce04f76d4.setContent(html_dc4791cccfb1d8aa3a5db5198d4592b5);
#
#
#
#         marker_b

# %% [markdown]
# ### Données brutes

# %%
from tabulate import tabulate
# if data is not None:
#     print(tabulate(df, headers="keys", tablefmt="fancy_grid"))

print(df.data.head())
# Out:
# 0    {'libelle_station': 'PECH DAVID', 'date_prelev...
# 1    {'libelle_station': 'La Garonne au Syndicat Ce...
# 2    {'libelle_station': 'La Sausse à Toulouse', 'd...
# 3    {'libelle_station': 'La Garonne à Blagnac', 'd...
# 4    {'libelle_station': 'Le Bras inférieur Garonne...
# Name: data, dtype: object

# %% [markdown]
# ## Test permettant d'interroger les prélèvements en eau de l'API Prélèvements en eau
#
# Lien : https://hubeau.eaufrance.fr/page/api-prelevements-eau

# %%
# url_prelev_eau = "https://hubeau.eaufrance.fr/api/v1/prelevements/referentiel/ouvrages?nom_commune=Toulouse&pretty"
url_prelev_eau = "https://hubeau.eaufrance.fr/api/v1/prelevements/chroniques"
# https://hubeau.eaufrance.fr/api/v1/prelevements/referentiel/ouvrages?nom_commune=Toulouse&pretty&fields=longitude,latitude,nom_ouvrage
params_prelev_eau = {
    "nom_commune": "Toulouse",
    "annee": 2022,
    "fields": "code_ouvrage,nom_ouvrage,longitude,latitude,annee,volume,code_mode_obtention_volume,code_usage"
}

data_prelev_eau = requete_api(url_prelev_eau, params=params_prelev_eau)

if data_prelev_eau is not None:
    df_prelev_eau = pd.DataFrame(data_prelev_eau)

# %% [markdown]
# ### Visualisation des ouvrages de prélèvements

# %%
# Créer une carte
f = folium.Figure(width=800, height=800)
m2 = folium.Map(location=[43.602566, 1.397389], zoom_start=13).add_to(f)

# Ajouter SOLAGRO à la carte
folium.Marker([43.602566, 1.397389], popup='SOLAGRO', icon=folium.Icon(color='red')).add_to(m2)

lon = df_prelev_eau.data.apply(lambda x: x['longitude']).values
lat = df_prelev_eau.data.apply(lambda x: x['latitude']).values
libelle_station = df_prelev_eau.data.apply(lambda x: x['nom_ouvrage']).values

for i in range(len(lon)):
    folium.Marker(location=[lat[i], lon[i]], popup=libelle_station[i]).add_to(m2)

display(m2)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2edc5f8fa747b3835adbd5ac3f6092db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2edc5f8fa747b3835adbd5ac3f6092db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2edc5f8fa747b3835adbd5ac3f6092db = L.map(
#                 &quot;map_2edc5f8fa747b3835adbd5ac3f6092db&quot;,
#                 {
#                     center: [43.602566, 1.397389],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f552a3d1afd459cbcf2a5eb690968e91 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f552a3d1afd459cbcf2a5eb690968e91.addTo(map_2edc5f8fa747b3835adbd5ac3f6092db);
#
#
#             var marker_40bd1fd4bb5054a597ab5e8e25a8e003 = L.marker(
#                 [43.602566, 1.397389],
#                 {}
#             ).addTo(map_2edc5f8fa747b3835adbd5ac3f6092db);
#
#
#             var icon_864e5885971c11169edaa90fe266b552 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_40bd1fd4bb5054a597ab5e8e25a8e003.setIcon(icon_864e5885971c11169edaa90fe266b552);
#
#
#         var popup_d7e817e4a52c880ef1a5fa17f5d1b6f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5f3ecd688f970e190edeae814bb55769 = $(`&lt;div id=&quot;html_5f3ecd688f970e190edeae814bb55769&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SOLAGRO&lt;/div&gt;`)[0];
#                 popup_d7e817e4a52c880ef1a5fa17f5d1b6f0.setContent(html_5f3ecd688f970e190edeae814bb55769);
#
#
#
#         marker_40bd1fd4bb5054a597ab5e8e25a8e003.bindPopup(popup_d7e817e4a52c880ef1a5fa17f5d1b6f0)
#         ;
#
#
#
#
#             var marker_be98a6c429c25a15014eab3dd9e3ed68 = L.marker(
#                 [43.58194415603316, 1.3986062175210023],
#                 {}
#             ).addTo(map_2edc5f8fa747b3835adbd5ac3f6092db);
#
#
#         var popup_ca0c03f88591965be7ebe7df1e4175f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dc0798627372a7203110872d80ec73a3 = $(`&lt;div id=&quot;html_dc0798627372a7203110872d80ec73a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SOC. D&#x27;EXPLOITATION THERMIQUE DU MIRAIL&lt;/div&gt;`)[0];
#                 popup_ca0c03f88591965be7ebe7df1e4175f0.setContent(html_dc0798627372a7203110872d80ec73a3);
#
#
#
#         marker_be98a6c429c25a15014eab3dd9e3ed68.bindPopup(popup_ca0c03f88591965be7ebe7df1e4175f0)
#         ;
#
#
#
#
#             var marker_672e5bb11d0adbf6cfe1957c81521578 = L.marker(
#                 [43.611578232321754, 1.3900005288508819],
#                 {}
#             ).addTo(map_2edc5f8fa747b3835adbd5ac3f6092db);
#
#
#         var popup_688f36d0b2e93534ebba459c91507048 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_800f2c70167f133cd9c404a7857aa499 = $(`&lt;div id=&quot;html_800f2c70167f133cd9c404a7857aa499&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;LA MERIDIONALE DES&lt;/div&gt;`)[0];
#                 popup_688f36d0b2e93534ebba459c91507048.setContent(html_800f2c70167f133cd9c404a7857aa499);
#
#
#
#         marker_672e5bb11d0adbf6cfe1957c81521578.bindPopup(popup_688f36d0b2e93534ebba459c91507048)
#         ;
#
#
#
#
#             var marker_db40fb370b927934656121ade1aa0f57 = L.marker(
#                 [43.60934960268563, 1.419486472864847],
#                 {}
#             ).addTo(map_2edc5f8fa747b3835adbd5ac3f6092db);
#
#
#         var popup_a228b287e85dea3c6f9b2ec93cfbab31 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3eb3a07603e966c4b3f55ad05a9554b6 = $(`&lt;div id=&quot;html_3eb3a07603e966c4b3f55ad05a9554b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;LA MERIDIONALE DES&lt;/div&gt;`)[0];
#                 popup_a228b287e85dea3c6f9b2ec93cfbab31.setContent(html_3eb3a07603e966c4b3f55ad05a9554b6);
#
#
#
#         marker_db40fb370b927934656121ade1aa0f57.bindPopup(popup_a228b287e85dea3c6f9b2ec93cfbab31)
#         ;
#
#
#
#
#             var marker_803b27759830dde96e8ec3beb224bcf7 = L.marker(
#                 [43.60934960268563, 1.419486472864847],
#                 {}
#             ).addTo(map_2edc5f8fa747b3835adbd5ac3f6092db);
#
#
#         var popup_801f6c930795b4191255a6a1f70e6c79 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ddad63f8cbf6771ae5f2c6d12d23dff1 = $(`&lt;div id=&quot;html_ddad63f8cbf6771ae5f2c6d12d23dff1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;LA MERIDIONALE DES&lt;/div&gt;`)[0];
#                 popup_801f6c930795b4191255a6a1f70e6c79.setContent(html_ddad63f8cbf6771

# %% [markdown]
# ### Données brutes

# %%
print(df_prelev_eau.data.head())
# Out:
# 0    {'code_ouvrage': 'OPR0000013335', 'annee': 202...
# 1    {'code_ouvrage': 'OPR0000030021', 'annee': 202...
# 2    {'code_ouvrage': 'OPR0000030023', 'annee': 202...
# 3    {'code_ouvrage': 'OPR0000030024', 'annee': 202...
# 4    {'code_ouvrage': 'OPR0000030025', 'annee': 202...
# Name: data, dtype: object

# %% [markdown]
# ## Test permettant d'interroger les ventes/achats de pesticides de l'API ente et achat de produits phytopharmaceutiques
#
# Lien : https://hubeau.eaufrance.fr/page/api-vente-et-achat-de-produits-phytopharmaceutiques#/

# %%
url_phyto = "https://hubeau.eaufrance.fr/api/v1/vente_achat_phyto/achats/produits"
params_phyto = {
    "type_territoire": "Zone postale",
    "code_territoire": "31000",
    "annee_min": 2020,
    "annee_max": 2024,
    "fields": "achat_etranger,annee,amm,code_territoire,eaj,quantite,unite"
}

data_phyto = requete_api(url_phyto, params=params_phyto)

if data_phyto is not None:
    df_phyto = pd.DataFrame(data_phyto)

# %%
df_phyto.data.head()
# Out:
# 0    {'annee': 2023, 'achat_etranger': 'Non', 'unit...
# 1    {'annee': 2023, 'achat_etranger': 'Non', 'unit...
# 2    {'annee': 2023, 'achat_etranger': 'Non', 'unit...
# 3    {'annee': 2023, 'achat_etranger': 'Non', 'unit...
# 4    {'annee': 2023, 'achat_etranger': 'Non', 'unit...
# Name: data, dtype: object
